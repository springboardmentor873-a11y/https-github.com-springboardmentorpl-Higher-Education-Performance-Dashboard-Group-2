# %%
# Handling Missing Values in QS Ranking Dataset
# Import required libraries

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# 1. Load Dataset

df = pd.read_csv("/content/2026_QS_World University_Rankings.csv")


# Display first 5 rows

print("First 5 rows of dataset:")
print(df.head())

# 2. Dataset Information

print("\nDataset Information:")
print(df.info())


# Shape of dataset

print("\nDataset Shape:")
print(df.shape)



# ==========================================
# 3. Check Missing Values
# ==========================================

print("\nMissing Values in Each Column:")
print(df.isnull().sum())


print("\nTotal Missing Values:")
print(df.isnull().sum().sum())



# ==========================================
# 4. Separate Numerical and Categorical Columns
# ==========================================

numerical_cols = df.select_dtypes(
    include=['int64','float64']
).columns


categorical_cols = df.select_dtypes(
    include=['object']
).columns



print("\nNumerical Columns:")
print(list(numerical_cols))


print("\nCategorical Columns:")
print(list(categorical_cols))



# ==========================================
# 5. Handle Numerical Missing Values
#    Replace with Mean
# ==========================================

num_imputer = SimpleImputer(strategy='mean')


df[numerical_cols] = num_imputer.fit_transform(
    df[numerical_cols]
)



# ==========================================
# 6. Handle Categorical Missing Values
#    Replace with Mode
# ==========================================

cat_imputer = SimpleImputer(strategy='most_frequent')


df[categorical_cols] = cat_imputer.fit_transform(
    df[categorical_cols]
)



# ==========================================
# 7. Check Missing Values After Cleaning
# ==========================================

print("\nMissing Values After Handling:")
print(df.isnull().sum())


print("\nTotal Missing Values After Cleaning:")
print(df.isnull().sum().sum())



# ==========================================
# 8. Display Cleaned Dataset
# ==========================================

print("\nCleaned Dataset:")
print(df.head())



# ==========================================
# 9. Save Clean Dataset
# ==========================================

df.to_csv(
    "QS_Ranking_Cleaned_Dataset.csv",
    index=False
)


print("\nDataset cleaned and saved successfully!")
# Out:
# First 5 rows of dataset:
#   QS_Rank Previous Rank                                         Name  \
# 0       1             1  Massachusetts Institute of Technology (MIT)
# 1       2             2                      Imperial College London
# 2       3             6                          Stanford University
# 3       4             3                         University of Oxford
# 4       5             4                           Harvard University
#
#           Country/Territory    Region Size Focus Research  \
# 0  United States of America  Americas    M    CO       VH
# 1            United Kingdom    Europe    L    FO       VH
# 2  United States of America  Americas    L    FC       VH
# 3            United Kingdom    Europe    L    FC       VH
# 4  United States of America  Americas    L    FC       VH
#
#                    Status  Academic Reputation SCORE  \
# 0  Private not for Profit                      100.0
# 1                  Public                       99.6
# 2  Private not for Profit                      100.0
# 3                  Public                      100.0
# 4  Private not for Profit                      100.0
#
#    Employer Reputation SCORE  Faculty Student Ratio SCORE  \
# 0                      100.0                        100.0
# 1                      100.0                         99.3
# 2                      100.0                        100.0
# 3                      100.0                        100.0
# 4                      100.0                         98.3
#
#    Citations per Faculty SCORE  International Faculty  SCORE  \
# 0                        100.0                         100.0
# 1                         95.0                         100.0
# 2                         99.7                          94.2
# 3                         91.0                          98.8
# 4                        100.0                          79.1
#
#    International Student SCORE  International Students Diversity SCORE  \
# 0                         91.6                                    92.3
# 1                        100.0                                   100.0
# 2                         73.5                                    76.1
# 3                         98.6                                    98.7
# 4                         81.4                                    60.6
#
#    International Research Network SCORE  Employment Outcomes SCORE  \
# 0                                  94.1                      100.0
# 1                                  97.5                       95.9
# 2                                  96.5                      100.0
# 3                                 100.0                      100.0
# 4                                  99.4                      100.0
#
#    Sustainability SCORE QS_Overall_Score
# 0                  93.8              100
# 1                  98.3             99.4
# 2                  95.4             98.9
# 3                  77.9             97.9
# 4                  77.8             97.7
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504 entries, 0 to 1503
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   QS_Rank                                 1504 non-null   object
#  1   Previous Rank                           1389 non-null   object
#  2   Name                                    1504 non-null   object
#  3   Country/Territory                       1504 non-null   object
#  4   Region                                  1504 non-null   object
#  5   Size                                    1503 non-null   object
#  6   Focus                                   1504 non-null   object
#  7   Research                                1503 non-null   object
#  8   Status                                  1456 non-null   object
#  9   Academic Reputation SCORE               1504 non-null   float64
#  10  Employer Reputation SCORE               1504 non-null   float64
#  11  Faculty Student Ratio SCORE             1504 non-null   float64
#  12  Citations per Faculty SCORE             1504 non-null   float64
#  13  International Faculty  SCORE            1417 non-null   float64
#  14  International Student SCORE             1467 non-null   float64
#  15  International Students Diversity SCORE  1467 non-null   float64
#  16  International Research Network SCORE    1502 non-null   float64
#  17  Employment Outcomes SCORE               1504 non-null   float64
#  18  Sustainability SCORE                    1480 non-null   float64
#  19  QS_Overall_Score                        1504 non-null   object
# dtypes: float64(10), object(10)
# memory usage: 235.1+ KB
# None
#
# Dataset Shape:
# (1504, 20)
#
# Missing Values in Each Column:
# QS_Rank                                     0
# Previous Rank                             115
# Name                                        0
# Country/Territory                           0
# Region                                      0
# Size                                        1
# Focus                                       0
# Research                                    1
# Status                                     48
# Academic Reputation SCORE                   0
# Employer Reputation SCORE                   0
# Faculty Student Ratio SCORE                 0
# Citations per Faculty SCORE                 0
# International Faculty  SCORE               87
# International Student SCORE                37
# International Students Diversity SCORE     37
# International Research Network SCORE        2
# Employment Outcomes SCORE                   0
# Sustainability SCORE                       24
# QS_Overall_Score                            0
# dtype: int64
#
# Total Missing Values:
# 352
#
# Numerical Columns:
# ['Academic Reputation SCORE', 'Employer Reputation SCORE', 'Faculty Student Ratio SCORE', 'Citations per Faculty SCORE', 'International Faculty  SCORE', 'International Student SCORE', 'International Students Diversity SCORE', 'International Research Network SCORE', 'Employment Outcomes SCORE', 'Sustainability SCORE']
#
# Categorical Columns:
# ['QS_Rank', 'Previous Rank', 'Name', 'Country/Territory', 'Region', 'Size', 'Focus', 'Research', 'Status', 'QS_Overall_Score']
#
# Missing Values After Handling:
# QS_Rank                                   0
# Previous Rank                             0
# Name                                      0
# Country/Territory                         0
# Region                                    0
# Size                                      0
# Focus                                     0
# Research                                  0
# Status                                    0
# Academic Reputation SCORE                 0
# Employer Reputation SCORE                 0
# Faculty Student Ratio SCORE               0
# Citations per Faculty SCORE               0
# International Faculty  SCORE              0
# International Student SCORE               0
# International Students Diversity SCORE    0
# International Research Network SCORE      0
# Employment Outcomes SCORE                 0
# Sustainability SCORE                      0
# QS_Overall_Score                          0
# dtype: int64
#
# Total Missing Values After Cleaning:
# 0
#
# Cleaned Dataset:
#   QS_Rank Previous Rank                                         Name  \
# 0       1             1  Massachusetts Institute of Technology (MIT)
# 1       2             2                      Imperial College London
# 2       3             6                          Stanford University
# 3       4             3                         University of Oxford
# 4       5             4                           Harvard University
#
#           Country/Territory    Region Size Focus Research  \
# 0  United States of America  Americas    M    CO       VH
# 1            United Kingdom    Europe    L    FO       VH
# 2  United States of America  Americas    L    FC       VH
# 3            United Kingdom    Europe    L    FC       VH
# 4  United States of America  Americas    L    FC       VH
#
#                    Status  Academic Reputation SCORE  \
# 0  Private not for Profit                      100.0
# 1                  Public                       99.6
# 2  Private not for Profit                      100.0
# 3                  Public                      100.0
# 4  Private not for Profit                      100.0
#
#    Employer Reputation SCORE  Faculty Student Ratio SCORE  \
# 0                      100.0                        100.0
# 1                      100.0                         99.3
# 2                      100.0                        100.0
# 3                      100.0                        100.0
# 4                      100.0                         98.3
#
#    Citations per Faculty SCORE  International Faculty  SCORE  \
# 0                        100.0                         100.0
# 1                         95.0                         100.0
# 2                         99.7                          94.2
# 3                         91.0                          98.8
# 4                        100.0                          79.1
#
#    International Student SCORE  International Students Diversity SCORE  \
# 0                         91.6                                    92.3
# 1                        100.0                                   100.0
# 2                         73.5                                    76.1
# 3                         98.6                                    98.7
# 4                         81.4                                    60.6
#
#    International Research Network SCORE  Employment Outcomes SCORE  \
# 0                                  94.1                      100.0
# 1                                  97.5                       95.9
# 2                                  96.5                      100.0
# 3                                 100.0                      100.0
# 4                                  99.4                      100.0
#
#    Sustainability SCORE QS_Overall_Score
# 0                  93.8              100
# 1                  98.3             99.4
# 2                  95.4             98.9
# 3                  77.9             97.9
# 4                  77.8             97.7
#
# Dataset cleaned and saved successfully!

# %%
# =====================================================
# Missing Value Handling - World University Rankings 2026
# =====================================================


# Import Libraries

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer



# =====================================================
# 1. Load Dataset
# =====================================================

df = pd.read_csv("/content/world_university_rankings_2026.csv")


# Display first rows

print("First 5 rows:")
print(df.head())



# =====================================================
# 2. Dataset Information
# =====================================================

print("\nDataset Information:")
df.info()


print("\nDataset Shape:")
print(df.shape)



# =====================================================
# 3. Check Missing Values
# =====================================================

print("\nMissing Values in Each Column:")
print(df.isnull().sum())


print("\nTotal Missing Values:")
print(df.isnull().sum().sum())



# =====================================================
# 4. Separate Column Types
# =====================================================


# Numerical columns

numerical_cols = df.select_dtypes(
    include=['int64','float64']
).columns


# Categorical columns

categorical_cols = df.select_dtypes(
    include=['object']
).columns


# Boolean columns

boolean_cols = df.select_dtypes(
    include=['bool']
).columns



print("\nNumerical Columns:")
print(list(numerical_cols))


print("\nCategorical Columns:")
print(list(categorical_cols))


print("\nBoolean Columns:")
print(list(boolean_cols))



# =====================================================
# 5. Handle Numerical Missing Values
#    Using Mean
# =====================================================

num_imputer = SimpleImputer(
    strategy="mean"
)


df[numerical_cols] = num_imputer.fit_transform(
    df[numerical_cols]
)



# =====================================================
# 6. Handle Categorical Missing Values
#    Using Mode
# =====================================================

cat_imputer = SimpleImputer(
    strategy="most_frequent"
)


df[categorical_cols] = cat_imputer.fit_transform(
    df[categorical_cols]
)



# =====================================================
# 7. Handle Boolean Missing Values
#    Using Mode
# =====================================================
# Based on the df.isnull().sum() output, the boolean column 'ranked_in_all_3' has no missing values.
# Therefore, this step is not needed. If there were missing boolean values, consider converting to int (0/1) or object type first.
# bool_imputer = SimpleImputer(
#     strategy="most_frequent"
# )


# df[boolean_cols] = bool_imputer.fit_transform(
#     df[boolean_cols]
# )



# =====================================================
# 8. Verify Missing Values
# =====================================================

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())


print("\nTotal Missing Values After Cleaning:")
print(df.isnull().sum().sum())



# =====================================================
# 9. Display Clean Dataset
# =====================================================

print("\nCleaned Dataset:")
print(df.head())



# =====================================================
# 10. Save Cleaned Dataset
# =====================================================

df.to_csv(
    "world_university_rankings_2026_cleaned.csv",
    index=False
)


print("\nCleaned dataset saved successfully!")
# Out:
# First 5 rows:
#                 university country         region university_type  \
# 0                      MIT     USA  North America         Private
# 1  Imperial College London      UK         Europe          Public
# 2      Stanford University     USA  North America         Private
# 3     University of Oxford      UK         Europe          Public
# 4       Harvard University     USA  North America         Private
#
#    qs_rank_2026  the_rank_2026  arwu_rank_2025  qs_score  the_score  \
# 0           1.0            2.0             3.0     100.0       96.4
# 1           2.0            8.0             NaN      99.2       86.1
# 2           3.0            5.0             2.0      99.1       95.5
# 3           4.0            1.0             6.0      98.9       97.0
# 4           5.0            5.0             1.0      98.8       95.5
#
#    arwu_score  ...  the_intl_outlook  founded  total_students  \
# 0       100.0  ...              74.2     1861           11858
# 1         NaN  ...              55.2     1907           19000
# 2        76.5  ...              88.4     1885           17249
# 3        72.4  ...              66.4     1096           24000
# 4       100.0  ...              77.4     1636           21000
#
#    intl_students_pct  nobel_laureates  fields_medalists  ranked_in_all_3  \
# 0                 34              100                 1             True
# 1                 61               15                 0            False
# 2                 24               85                22             True
# 3                 41               72                 0             True
# 4                 25              162                 4             True
#
#    avg_rank_all3  university_age_2026  \
# 0            2.0                  165
# 1            5.0                  119
# 2            3.3                  141
# 3            3.7                  930
# 4            3.7                  390
#
#                                  data_sources
# 0  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 1  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 2  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 3  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 4  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
#
# [5 rows x 30 columns]
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   university            57 non-null     object
#  1   country               57 non-null     object
#  2   region                57 non-null     object
#  3   university_type       57 non-null     object
#  4   qs_rank_2026          56 non-null     float64
#  5   the_rank_2026         55 non-null     float64
#  6   arwu_rank_2025        19 non-null     float64
#  7   qs_score              56 non-null     float64
#  8   the_score             55 non-null     float64
#  9   arwu_score            19 non-null     float64
#  10  qs_academic_rep       56 non-null     float64
#  11  qs_employer_rep       56 non-null     float64
#  12  qs_faculty_student    56 non-null     float64
#  13  qs_citations          56 non-null     float64
#  14  qs_intl_faculty       56 non-null     float64
#  15  qs_intl_students      56 non-null     float64
#  16  the_teaching          55 non-null     float64
#  17  the_research_env      55 non-null     float64
#  18  the_research_quality  55 non-null     float64
#  19  the_industry          55 non-null     float64
#  20  the_intl_outlook      55 non-null     float64
#  21  founded               57 non-null     int64
#  22  total_students        57 non-null     int64
#  23  intl_students_pct     57 non-null     int64
#  24  nobel_laureates       57 non-null     int64
#  25  fields_medalists      57 non-null     int64
#  26  ranked_in_all_3       57 non-null     bool
#  27  avg_rank_all3         57 non-null     float64
#  28  university_age_2026   57 non-null     int64
#  29  data_sources          57 non-null     object
# dtypes: bool(1), float64(18), int64(6), object(5)
# memory usage: 13.1+ KB
#
# Dataset Shape:
# (57, 30)
#
# Missing Values in Each Column:
# university               0
# country                  0
# region                   0
# university_type          0
# qs_rank_2026             1
# the_rank_2026            2
# arwu_rank_2025          38
# qs_score                 1
# the_score                2
# arwu_score              38
# qs_academic_rep          1
# qs_employer_rep          1
# qs_faculty_student       1
# qs_citations             1
# qs_intl_faculty          1
# qs_intl_students         1
# the_teaching             2
# the_research_env         2
# the_research_quality     2
# the_industry             2
# the_intl_outlook         2
# founded                  0
# total_students           0
# intl_students_pct        0
# nobel_laureates          0
# fields_medalists         0
# ranked_in_all_3          0
# avg_rank_all3            0
# university_age_2026      0
# data_sources             0
# dtype: int64
#
# Total Missing Values:
# 98
#
# Numerical Columns:
# ['qs_rank_2026', 'the_rank_2026', 'arwu_rank_2025', 'qs_score', 'the_score', 'arwu_score', 'qs_academic_rep', 'qs_employer_rep', 'qs_faculty_student', 'qs_citations', 'qs_intl_faculty', 'qs_intl_students', 'the_teaching', 'the_research_env', 'the_research_quality', 'the_industry', 'the_intl_outlook', 'founded', 'total_students', 'intl_students_pct', 'nobel_laureates', 'fields_medalists', 'avg_rank_all3', 'university_age_2026']
#
# Categorical Columns:
# ['university', 'country', 'region', 'university_type', 'data_sources']
#
# Boolean Columns:
# ['ranked_in_all_3']
#
# Missing Values After Cleaning:
# university              0
# country                 0
# region                  0
# university_type         0
# qs_rank_2026            0
# the_rank_2026           0
# arwu_rank_2025          0
# qs_score                0
# the_score               0
# arwu_score              0
# qs_academic_rep         0
# qs_employer_rep         0
# qs_faculty_student      0
# qs_citations            0
# qs_intl_faculty         0
# qs_intl_students        0
# the_teaching            0
# the_research_env        0
# the_research_quality    0
# the_industry            0
# the_intl_outlook        0
# founded                 0
# total_students          0
# intl_students_pct       0
# nobel_laureates         0
# fields_medalists        0
# ranked_in_all_3         0
# avg_rank_all3           0
# university_age_2026     0
# data_sources            0
# dtype: int64
#
# Total Missing Values After Cleaning:
# 0
#
# Cleaned Dataset:
#                 university country         region university_type  \
# 0                      MIT     USA  North America         Private
# 1  Imperial College London      UK         Europe          Public
# 2      Stanford University     USA  North America         Private
# 3     University of Oxford      UK         Europe          Public
# 4       Harvard University     USA  North America         Private
#
#    qs_rank_2026  the_rank_2026  arwu_rank_2025  qs_score  the_score  \
# 0           1.0            2.0        3.000000     100.0       96.4
# 1           2.0            8.0       18.421053      99.2       86.1
# 2           3.0            5.0        2.000000      99.1       95.5
# 3           4.0            1.0        6.000000      98.9       97.0
# 4           5.0            5.0        1.000000      98.8       95.5
#
#    arwu_score  ...  the_intl_outlook  founded  total_students  \
# 0  100.000000  ...              74.2   1861.0         11858.0
# 1   65.089474  ...              55.2   1907.0         19000.0
# 2   76.500000  ...              88.4   1885.0         17249.0
# 3   72.400000  ...              66.4   1096.0         24000.0
# 4  100.000000  ...              77.4   1636.0         21000.0
#
#    intl_students_pct  nobel_laureates  fields_medalists  ranked_in_all_3  \
# 0               34.0            100.0               1.0             True
# 1               61.0             15.0               0.0            False
# 2               24.0             85.0              22.0             True
# 3               41.0             72.0               0.0             True
# 4               25.0            162.0               4.0             True
#
#    avg_rank_all3  university_age_2026  \
# 0            2.0                165.0
# 1            5.0                119.0
# 2            3.3                141.0
# 3            3.7                930.0
# 4            3.7                390.0
#
#                                  data_sources
# 0  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 1  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 2  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 3  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
# 4  QS Jun-2025 | THE Oct-2025 | ARWU Aug-2025
#
# [5 rows x 30 columns]
#
# Cleaned dataset saved successfully!
